# %%
import pandas as pd
from pandas import Series, DataFrame

import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import math


# %matplotlib inline

# %%
titanic_df = pd.read_csv("C:\\Users\\malli\\Downloads\\titanic\\train.csv")

# %%
titanic_df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
titanic_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
# PassengerId    891 non-null int64
# Survived       891 non-null int64
# Pclass         891 non-null int64
# Name           891 non-null object
# Sex            891 non-null object
# Age            714 non-null float64
# SibSp          891 non-null int64
# Parch          891 non-null int64
# Ticket         891 non-null object
# Fare           891 non-null float64
# Cabin          204 non-null object
# Embarked       889 non-null object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.6+ KB

# %%
sns.barplot( y = count('Survived'), x ='Sex', data = titanic_df)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-196-c7ca7fc4deea> in <module>
# ----> 1 sns.barplot( y = count('Survived'), x ='Sex', data = titanic_df)
#
# NameError: name 'count' is not defined

# %%
sns.catplot(x='Sex', y ='PassengerId', data=titanic_df)

# %%
sns.countplot( 'Pclass', data = titanic_df,hue = 'Sex')

# %%
sns.countplot( 'Sex', data = titanic_df)

# %%
titanic_df[["Sex","Age","Pclass"]].head()
# Out:
#       Sex   Age  Pclass
# 0    male  22.0       3
# 1  female  38.0       1
# 2  female  26.0       3
# 3  female  35.0       1
# 4    male  35.0       3

# %%
def display_Titanic(arg1):
    print("hello test")
    Age = arg1["Age"]
    print(Age)
    Sex = arg1["Sex"]
    print(Sex)

# %%
display_Titanic(titanic_df[["Sex","Age"]].head())
# Out:
# hello test
# 0    22.0
# 1    38.0
# 2    26.0
# 3    35.0
# 4    35.0
# Name: Age, dtype: float64
# 0      male
# 1    female
# 2    female
# 3    female
# 4      male
# Name: Sex, dtype: object

# %%
def display_Titanic(arg1):
    
    if arg1["Age"] < 16:
        return ("child")
    else:
        return (arg1["Sex"])

# %%
titanic_df["Person"] = titanic_df[["Age","Sex"]].apply(display_Titanic,axis =1)

# %%
titanic_df[0:10]
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
# 5            6         0       3
# 6            7         0       1
# 7            8         0       3
# 8            9         1       3
# 9           10         1       2
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
# 5                                   Moran, Mr. James    male   NaN      0
# ...

# %%
sns.countplot(x="Pclass",data = titanic_df, hue = "Person")

# %%
titanic_df.median()
# Out:
# PassengerId    446.0000
# Survived         0.0000
# Pclass           3.0000
# Age             28.0000
# SibSp            0.0000
# Parch            0.0000
# Fare            14.4542
# dtype: float64

# %%
titanic_df.mean()
# Out:
# PassengerId    446.000000
# Survived         0.383838
# Pclass           2.308642
# Age             29.699118
# SibSp            0.523008
# Parch            0.381594
# Fare            32.204208
# dtype: float64

# %%
titanic_df["Person"].value_counts()
# Out:
# male      537
# female    271
# child      83
# Name: Person, dtype: int64

# %%
titanic_df["Sex"].value_counts()
# Out:
# male      577
# female    314
# Name: Sex, dtype: int64

# %%
titanic_df["Age"].hist(bins = 70)
#titanic_df["Sex"].hist()

# %%
#titanic_df["Sex"].hist(bins = 70)

# %%
fg1 = sns.FacetGrid(data = titanic_df, col = 'Person',aspect = 1)
fg1.map(plt.hist,"Age")

# %%
fg2 = sns.FacetGrid(data = titanic_df, hue = 'Pclass',aspect = 4)
fg2.map(sns.kdeplot,'Age',shade= True)
oldest = titanic_df['Age'].max()
fg2.set(xlim=(0,oldest))
fg2.add_legend()

# %%
print(titanic_df['Age'].max())
print(titanic_df['Age'].min())
print(titanic_df['Age'].mean())
# Out:
# 80.0
# 0.42
# 29.69911764705882

# %%
deck = titanic_df['Cabin']

# %%
deck.head()
# Out:
# 0     NaN
# 1     C85
# 2     NaN
# 3    C123
# 4     NaN
# Name: Cabin, dtype: object

# %%
deck1 = titanic_df['Cabin'].dropna()

# %%
deck1.head()
# Out:
# 1      C85
# 3     C123
# 6      E46
# 10      G6
# 11    C103
# Name: Cabin, dtype: object

# %%
deck_list = []

for i in deck:
    if pd.notna(i):
        deck_list.append(i[0])
    else:
        deck_list.append("3")
        
            
titanic_df['deck_list'] = DataFrame(deck_list)

# %%
titanic_df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked  Person deck_list
# 0      0         A/5 21171   7.2500   NaN        S    male         3
# 1      0          PC 17599  71.2833   C85        C  female         C
# 2      0  STON/O2. 3101282   7.9250   NaN        S  female         3
# ...

# %%
sns.countplot(x="Pclass",data = titanic_df, hue = "deck_list")

# %%
deck_df.drop(columns = 0)

deck_list1 = []

for i in deck1:
        deck_list1.append(i[0])
        
deck_df4 =   DataFrame(deck_list1)     
deck_df4.columns = ["Deck"]
            
sns.countplot('Deck',data=deck_df4,palette='winter_d')

# %%
deck_df4.head()
# Out:
#   Deck
# 0    C
# 1    C
# 2    E
# 3    G
# 4    C

# %%
sns.countplot('Embarked',data=titanic_df, hue = "Pclass", order = ['C','Q','S'])

# %%
def family_check(arg1):
    if (arg1["SibSp"]+ arg1["Parch"]) > 0:
        return "Family"
    else:
        return "Alone"

# %%
titanic_df["Family"] = titanic_df[["SibSp","Parch"]].apply(family_check,axis =1)

# %%
titanic_df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked  Person deck_list  Family
# 0      0         A/5 21171   7.2500   NaN        S    male         3  Family
# 1      0          PC 17599  71.2833   C85        C  female         C  Family
# 2      0  STON/O2. 3101282   7.9250   NaN        S  female         3   Alone
# ...

# %%
sns.countplot('Pclass',data=titanic_df, hue = "Family")

# %%
sns.countplot('Family',data=titanic_df,palette='Blues')

# %%
sns.countplot('Survived',data=titanic_df,palette='Set1')

# %%
sns.lineplot(y='Survived', x= 'Pclass',data=titanic_df, err_style="bars", ci=68)

# %%
sns.lineplot(y='Survived', x= 'Pclass',data=titanic_df, err_style="bars", ci=68,hue = 'Person')

# %%
sns.lmplot(y='Survived', x= 'Age',data=titanic_df)

# %%
sns.lmplot(y='Survived', x= 'Age',data=titanic_df,hue = "Pclass",palette='winter')

# %%
generations=[10,20,40,60,80]
sns.lmplot('Age','Survived',hue='Pclass',data=titanic_df,palette='winter',x_bins=generations)

# %%
sns.lmplot('Age','Survived',hue='Person',data=titanic_df,palette='winter',x_bins=generations)

# %%
sns.lineplot(y='Survived', x= 'deck_list',data=titanic_df, err_style="bars", ci=68)

# %%
sns.lineplot(y='Survived', x= 'Cabin',data=titanic_df, err_style="bars", ci=68)

# %%
def family_count(arg1):
        return (arg1["SibSp"]+ arg1["Parch"])
    
    
titanic_df["Family_Count"] = titanic_df[["SibSp","Parch"]].apply(family_count,axis =1)

# %%
titanic_df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked  Person deck_list  Family  \
# 0      0         A/5 21171   7.2500   NaN        S    male         3  Family
# 1      0          PC 17599  71.2833   C85        C  female         C  Family
# 2      0  STON/O2. 3101282   7.9250   NaN        S  female         3   Alone
# ...

# %%
sns.lineplot(y='Survived', x= 'Family_Count',data=titanic_df, err_style="bars", ci=68)

# %%
titanic_df['Family_Count'].max()
# Out:
# 10.0

# %%
titanic_df.where(titanic_df["Family_Count"] == 10, inplace = True)
